# %% [markdown]
# # PLUMMER SPHERE DISTRIBUTION GENERATION ----> WITH PERTURBER

# %% [markdown]
# ## I want to add another particle, more massive

# %%
import numpy as np
from astropy import units as u
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random
from scipy.stats import uniform

# %% [markdown]
# # Units

# %%
#G_phy = 6.8e-8*u.cm*u.cm*u.cm/u.s/u.s/u.g
#G_iu = 1

#r_iu = 1 * u.au
#r_phy = r_iu.to(u.cm)

#M_iu = 1 * u.M_sun
#M_phy = M_iu.to(u.g)

#v_phy = np.sqrt(G_phy * M_phy / r_phy).to(u.km/u.s)
#t_phy = (r_phy / v_phy).to(u.yr)
#density_phy = (M_phy / (4/3 * np.pi * r_phy**3)).to(u.g/u.cm**3)
#a_phy = (G_phy * M_phy / r_phy**2).to(u.cm/u.s**2)

#E_phy = G_phy*(M_phy**2)/r_phy #cm^2 g s^-2 = erg

# %% [markdown]
# Values

# %%
# ---- 100 body with R = 1.5e15 cm , m = 2e33 g ----

#R_halo = 1e20
#m_points = 2e33
N_dim = 3

# %%
N = 10000
G_p = 6.67*10**(-8)*u.cm**3/(u.g*u.s**2)
G_iu = 1

# radius:
r_iu = 1*u.pc
r_p = r_iu.to(u.cm)

# mass:
M_iu = 1*u.M_sun
M_p = M_iu.to(u.g)

# scale factor :
b = 45

# my values:
m_points = 1*M_iu
R_halo = 2*b *r_iu



# the density of the cluster is given by:
rho_iu = N*(m_points/M_iu)/((4*np.pi*(R_halo/r_iu)**3)/3)
rho_p = N*M_p/((4*np.pi*(R_halo.to(u.cm))**3)/3)

# compute the collapse time:
cost = np.sqrt(3*np.pi/32)
tc_iu = cost/np.sqrt(G_iu*rho_iu)
tc_p = cost/np.sqrt(G_p*rho_p)

print("The mass of the stars - so my test particles - (in internal units) is: ", m_points/M_iu)
print("The radius of the cluster (in internal units) is: ", R_halo/r_iu)
print("The density of the cluster (in internal units) is: ", rho_iu)
print("The density of the cluster (in physical units) is: ", rho_p)
print("The collapse time (in internal units) is: ", tc_iu)
print("The collapse time (in physical units) is: ", tc_p)
# Out:
# The mass of the stars - so my test particles - (in internal units) is:  1.0
# The radius of the cluster (in internal units) is:  90.0
# The density of the cluster (in internal units) is:  0.003274793067734472
# The density of the cluster (in physical units) is:  2.216348943565359e-25 g / cm3
# The collapse time (in internal units) is:  9.48349988690498
# The collapse time (in physical units) is:  4463531346157704.5 s

# %% [markdown]
# # Random generation through spherical symmetry

# %%
def random_points(b):
    
    #theta = np.arccos(np.random.uniform(-1, 1))  
    #phi = np.random.uniform(0, 2*np.pi)     
    
    p =  np.random.uniform(0, 1, N)
    r = b * p**(1/3) * (1-p**(2/3))**(-1/2)
    phi = np.random.uniform(0, 1, N) * (2*np.pi)
    theta = np.arccos(1 - 2*np.random.uniform(0, 1, N))
    
    x = r * np.sin(theta) * np.cos(phi)
    y = r * np.sin(theta) * np.sin(phi)
    z = r * np.cos(theta)

    return r, x, y, z

# output: coordinates as tuple
n_points = [random_points(b) for _ in range(N)]
print(len(n_points[0]))

# output: coordinates as single vectors
#x_p = []
#y_p = []
#z_p = []

for _ in range(N):
    r, x, y, z = random_points(b)
    #x_p.append(x)
    #y_p.append(y)
    #z_p.append(z)
# Out:
# 4

# %% [markdown]
# Plots

# %%
plt.figure(figsize=(10,10))
ax = plt.axes(projection="3d")
#ax.scatter(x_p, y_p, z_p, color='black', s=10)
ax.scatter(x, y, z, color='lightseagreen', alpha = 0.4, s=10)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim(-90,90)
ax.set_ylim(-90,90)
ax.set_zlim(-90,90)


ax.set_title('Spherically symmetric generated random points')
plt.show()

# %% [markdown]
# # Sampling the velocities: Monte Carlo rejection method

# %% [markdown]
# q = v / (2 * phi)**(1/2)
#
# q va da 0 a 1 !!

# %% [markdown]
# ## I need to get the potential
#
# It is of the form
# $$\Phi = -\frac{M}{(b^2+r^2)^{1/2}}$$
# where we set $G = 1$ in our internal units.where we set $G = 1$ in our internal units.

# %%
pot =  -1 * N*m_points / (b**2 + r**2)**(1/2)

# %%
# plot:
plt.figure(figsize = (6,6))
plt.plot(r[np.argsort(r)], pot[np.argsort(r)], c='lightseagreen')
plt.title(r"$\Phi(r)$", fontsize=16)
plt.xlabel(r"$r$", fontsize=13)
plt.ylabel("$\Phi$", fontsize=13)
plt.margins(0.05, 0.05)
plt.show()

# %% [markdown]
# ## escape velocity

# %%
v_esc = (2 * (-1 * pot))**(1/2) * u.solMass**(-1/2)
print(v_esc)
#plot: 
plt.figure(figsize = (6,6))
plt.plot(r[np.argsort(r)], v_esc[np.argsort(r)], c='lightseagreen')
plt.title(r"$\vec{v}_{esc} (\vec{r})$", fontsize=16)
plt.xlabel(r"$\vec{r}$", fontsize=13)
plt.ylabel(r"$\vec{v}$", fontsize=13)
plt.margins(0.05, 0.05)
plt.show()

# %% [markdown]
# ## rejection sampling

# %%
def f_x (q):
    return (1 - q**2)**(7/2) * q**2 
def g_x(f_max):
    return f_max

# %%
# I take N q between 0 and 1
number_of_qs = 3*N

q_grid = np.linspace (0, 1, number_of_qs)

plt.figure(figsize = (6,6))

plt.plot(q_grid, f_x(q_grid), label="non-normalized f(q)", color='lightseagreen')
plt.xlabel("$q$s")
plt.ylabel("$f(q)$s counts")
plt.ylim(0, 0.1)
plt.legend(loc='upper right', fontsize='medium')
plt.show()

# %%
import scipy.integrate as integrate

import scipy.special as special

result = integrate.quad(lambda q_grid: f_x(q_grid), 0, 1)
print(result)
fq_normalized = f_x(q_grid) * 1/result[0]

plt.figure(figsize = (6,6))

plt.plot(q_grid, fq_normalized, label="normalized f(q)", color='lightseagreen')
plt.xlabel("$q$s")
plt.ylabel("$f(q)$s counts")
plt.ylim(0, 3)
plt.legend(loc='upper right', fontsize='medium')
plt.show()

# %%
#f_max = np.max(f_x(q_grid))

f_max = np.max(fq_normalized)

#let's generate unif in [0, g(x)] 
unif= np.random.uniform(0, g_x(f_max),number_of_qs)
y_accepted = []
for i in range(number_of_qs):
    #if unif[i] <= f_x(q_grid[i]):
    if unif[i] <= fq_normalized[i]:

        y_accepted.append(q_grid[i])

print(len(r), len(unif), len(y_accepted))

# %%
plt.figure(figsize = (6,6))
plt.plot(q_grid, fq_normalized, c='navy')
plt.hist(y_accepted, 50, density=True, color='lightseagreen', alpha=0.5, label='sampled q')

plt.title("$f(x)$", fontsize=16)
plt.xlabel("$x$", fontsize=13)
plt.ylabel("$f$", fontsize=13, rotation=0)
#plt.margins(0.05, 0.05)
plt.legend();

# %% [markdown]
# ### qui ho un problema: come associo ad un potenziale ( e quindi un raggio) la velocità? a caso? taglio il vettore v_esc casualmente??

# %%
from sklearn.utils import shuffle

y_accepted = np.array(y_accepted)
q_sample = shuffle(y_accepted)

q_ok = q_sample[:N]

v = q_ok * v_esc

plt.hist(v, 40, density=True, color='lightseagreen', alpha=0.5, label='v')
plt.legend()

# %% [markdown]
# # distribuzione delle boh...
# print(pot, v)
# print(pot.value - v)
# epsilon =-( pot.value - (1/2 * v**2))
# print(epsilon**(7/2))
# norm_factor = 10
# f_eps = epsilon **(7/2)
# print(f_eps)
# plt.scatter(v, epsilon**(7/2), color='lightseagreen', alpha=0.5, label='v')

# %% [markdown]
# ### Voglio ricavare la distribuzione delle velocità ---> così poi posso fare l'integrale per avere la decelerazione

# %%
psi =  1 * N*m_points / (b**2 + r**2)**(1/2)

v_linspace = np.linspace(0,50, len(psi))

f_eps = (psi.value -0.5 * v_linspace**2) **(7/2) 
plt.hist(v, 40, density=True, color='lightseagreen', alpha=0.5, label='v')
plt.plot(v_linspace, f_eps)

# %%
#defining thetha and phi:
phi = np.random.uniform(0, 1, N) * (2*np.pi)
theta = np.arccos(1 - 2*np.random.uniform(0, 1, N))
plt.hist(phi, 20, density=True, color='lightseagreen', alpha=0.5, label='phi')
plt.hist(theta, 40, density=True, color='thistle', alpha=0.7, label='theta')
plt.legend()
plt.title("Distribuzione angoli")


v_x = v * np.sin(theta) * np.cos(phi)
v_y = v * np.sin(theta) * np.sin(phi)
v_z = v * np.cos(theta)

# %%
fig = plt.figure(figsize = (6,6))
ax = fig.add_subplot(projection='3d')
ax.scatter(v_x, v_y, v_z, c = 'lightseagreen', s=7.5, alpha=0.3)
ax.set_aspect('equal')
ax.set_xlabel('$v_x$')
ax.set_ylabel('$v_y$')
ax.set_zlabel('$v_z$')
ax.set_title(r'$\vec{v}$ distribution', fontsize=15)
#ax.set_xlim(-13, 13)
#ax.set_ylim(-13, 13)
#ax.set_zlim(-13, 13)
plt.show();

'''
plt.figure(figsize = (6,6))
a = v_esc * np.cos( phi ) *np.sin(theta)  # 1 is v = v_esc
c = v_esc * np.sin(theta) * np.sin(phi)
plt.scatter(v_x,v_y, c='lightseagreen', s=5, alpha=0.5)
plt.scatter(a, c, c='red', label='$v$ = $v_{esc}$')
plt.axis('equal')
#plt.xlim(-1.5,1.5)
#plt.ylim(-1.5,1.5)
plt.xlabel('x')
plt.xlabel('y')
plt.title('2D projection')
plt.legend();
'''

# %% [markdown]
# # Let's now add a perturber

# %% [markdown]
# We want to initialize a perturber in orbit in a Plummer sphere with two different masses: $M_1 = 0.03M_{\text{tot}}$ and $M_2 = 0.01M_{\text{tot}}$ to study the different behaviours.
#
# To initialize the position and the velocity of the perturber we need to make use of the equations for the conservation of energy and angular momentum on an unperturbed elliptical orbit with apoastron $R_{\text{apo}} = \frac{1}{3} R_{\text{peri}}$.
#
# In particular, the equations that must be satisfied are:
#
# $$ E(R_\text{apo};M(R_\text{apo})) = E(R_\text{peri};M(R_\text{peri}))   $$
#
# $$ L(R_\text{apo}) = L(R_\text{peri})  $$
#
# That can be written as:
#
# $$ \frac{1}{2} \mu v_\text{apo}^2 - \frac{GM(R_\text{apo})\mu}{\sqrt{b^2+R_{\text{apo}}^2}} = \frac{1}{2} \mu v_\text{peri}^2 - \frac{GM(R_\text{peri})\mu}{\sqrt{b^2+R_{\text{peri}}^2}} $$
#
# $$ \mu v_{\text{apo}} R_{\text{apo}} = \mu v_{\text{peri}} R_{\text{peri}} $$
#
# Since $M_\text{Plummer} >> M_\text{perturber}$, we can approximate: $\mu \simeq M_\text{perturber}$ and $M(R) =  M_\text{Plummer}(R)$
#
# Solving this system of equations we can get: $\vec{x_0} = (R_{\text{apo}},0,0)$ $\vec{v_0} = (0,v_{\text{apo}},0)$
#
# Where $R_{\text{apo}}=6 \text{IU} = 6\text{pc}$ and $v_\text{apo} = \frac{1}{2}\Bigl(\frac{GM(R_\text{peri})}{\sqrt{b^2+R_\text{peri}^2}} - \frac{GM(R_\text{apo})}{\sqrt{b^2+9R_\text{peri}^2}}\Bigr)^{1/2}$

# %% [markdown]
# def M_of_r(r):
#     return M_tot*r**3 /(b**3 * (1+r**2/(b**2))**(3/2))

# %%
num_points = N + 1
M_tot = m_points.value*N
m = m_points * np.ones(N) # define the array of masses

perturber_mass = m_points * 1000 

R_apo = 8 # define the apocentre
R_peri = 1/3*R_apo # define the pericetre

# define the mass enclosed in the apocentre and in the pericentre:
r_sorting = np.argsort(r)
m_r_sorted = m[r_sorting]
#M_apo = np.sum(m_r_sorted[r_sort<R_apo])
#M_peri = np.sum(m_r_sorted[r_sort<R_peri])

#print('numerical M_apo',M_apo, 'analytical M_apo', M_of_r(R_apo))
#print('numerical M_peri',M_peri, 'analytical M_peri', M_of_r(R_peri))

# compute the velocity at the apocentre
v_apo = 1/2 * ((G_iu*M_tot/(np.sqrt(R_peri**2+b**2))) - (G_iu*M_tot/(np.sqrt(9*R_peri**2+b**2))) )**(1/2)

x_pert = R_apo
y_pert = 0 
z_pert = 0

v_x_pert = 0 
v_y_pert = v_apo
v_z_pert = 0



'''
#perturber position 
r_pert = 1.5 * b
phi = np.random.uniform(0, 1, 1) * (2*np.pi)
theta = np.arccos(1 - 2*np.random.uniform(0, 1, 1))

x_pert = np.array(r_pert * np.sin(theta) * np.cos(phi), dtype = str)
y_pert = r_pert * np.sin(theta) * np.sin(phi)
z_pert = r_pert * np.cos(theta)

v_x_pert = v_pert * np.sin(theta) * np.cos(phi)
v_y_pert = v_pert * np.sin(theta) * np.sin(phi)
v_z_pert = v_pert * np.cos(theta)
'''
print(v_x_pert, v_y_pert, v_z_pert )

# %% [markdown]
# # Proviamo varie masse del perturber !!

# %%
masse_pert = [100, 500, 1000]

# %% [markdown]
# # Writing on file

# %%
#def w_onfile(filename, num_points, radius, masses, dimension, x, y, z):
 #   with open(filename, 'w') as file:
  #      file.write(f'  {num_points} \n  {dimension} \n  {0}  \n')
   #     for i in range(num_points):
    #        file.write(f'  {(masses/M_iu).value}  \n')
     #   for i in range(num_points):
      #      file.write(f'  {(x[i]/r_iu).value}  {(y[i]/r_iu).value}  {(z[i]/r_iu).value}  \n')
       # for i in range(num_points):
            #file.write(f'  {(vx[i]/v_iu).value}  {(vy[i]/v_iu).value}  {(vz[i]/v_iu).value}  \n')
        #    file.write(f'  {0}  {0}  {0}  \n')
            
#filename = 'treecode_in.txt'

#w_onfile(filename, N, R_halo, m_points, N_dim, x, y, z)

# %%
def w_onfile(filename, num_points, masses, dimension, x, y, z):
    with open(filename, 'w') as file:
        file.write(f'  {num_points} \n  {dimension} \n  {0}  \n')
        #perturber mass
        file.write(f'  {(perturber_mass/M_iu).value}  \n')
        #mass of the others
        for _ in range(num_points-1):
            file.write(f'  {(masses/M_iu).value}  \n')
        #perturber's position
        file.write(f'  {x_pert}  {y_pert}  {z_pert}  \n')
        #position of the others
        for i in range(num_points-1):
            file.write(f'  {x[i]}  {y[i]}  {z[i]}  \n')
        #perturber's velocity
        #file.write(f'  {v_x_pert[0]}  {v_y_pert[0]}  {v_z_pert[0]} \n')
        file.write(f'  {v_x_pert}  {v_y_pert}  {v_z_pert} \n')
        #velocities of the others
        for i in range(num_points-1):
            #file.write(f'  {(vx[i]/v_iu).value}  {(vy[i]/v_iu).value}  {(vz[i]/v_iu).value}  \n')
            file.write(f'  {v_x[i]}  {v_y[i]}  {v_z[i]} \n')

# %%
filename = 'treecode_in_mpert'+ str(perturber_mass)+'.txt'

w_onfile(filename, num_points, m_points, N_dim, x, y, z)

# %% [markdown]
# # let's calculate the timestep

# %%
#x at which we want to arrive, it has to be greter than softening
softening = 0.5
x_min = softening * 10

r_fortime = np.linspace(0, r_p/r_iu, 1000)
#acceleration in function of r:
a = G_iu * rho_iu *r_fortime * 4/3 * np.pi 
#print(a)

# %%
timestep = 0.001 * np.sqrt(x_min/max(a))
print(timestep, "internal units")
# Out:
# 0.019091883092036785 internal units

# %%
print("run: ./treecode in=treecode_in_4.txt out=treecode_out_4.txt dtime=0.001 eps=%f theta=0.1 tstop=10 dtout=0.1
 ", %softening, )
# Out:
#   Cell In[24], line 1
#     print("run: ./treecode in=treecode_in_4.txt out=treecode_out_4.txt dtime=0.001 eps=%f theta=0.1 tstop=10 dtout=0.1
#           ^
# SyntaxError: unterminated string literal (detected at line 1)
